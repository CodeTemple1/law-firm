# %%
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta http-equiv="X-UA-Compatible" content="IE=edge">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>NIELSEN, ZEHE & ANTAS, P.C.</title>

    <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/bootstrap@4.6.0/dist/css/bootstrap.min.css" integrity="sha384-B0vP5xmATw1+K9KRQjQERJvTumQW0nPEzvF6L/Z6nronJ3oUOFUFpCjEUQouq2+l" crossorigin="anonymous">
    <link rel="stylesheet" href="./static/css/main.css"/>

</head>

<body>
<main class="container"
    <div class="col-4 offset-4"</div>

    
<header>
    <div class="flex-container">
        <div style="flex-grow: 1">NZA</div>
        <div style="flex-grow: 8">NIELSEN, ZEHE & ANTAS, P.C.</div>
    </div>
    <hr>
    <nav class="navbar navbar-expand-lg navbar-light bg-light">
            <div class="navbar-nav">
                <a class="nav-link active" href="#">WHO WE ARE <span class="sr-only">(current)</span></a>
                <a class="nav-link active" href="#">WHAT WE DO</a>
                <a class="nav-link active" href="#">NEWS & EVENTS</a>
                <a class="nav-link active" href="#">WHERE WE WORK</a>
                <a class="nav-link active" href="#">CONTACT US</a>
            </div>
        </div>
    </nav>

    <hr> 

</header> 
<main>
    TEXT
    <img src="static\images\nza_slideshow.jpg" alt="NZA_slideshow">
    
    <div class="container">
        <div class="container">
            <img src="static\images\nav_side.jpg" alt="sidebar" style="width:20%;">
            <div class="top-right">News Feed</div>
        </div>
</main>  
<footer>
    <hr>
    <ul>
        <li><a href="whoweare">WHO WE ARE</a></li>
        <li><a href="whatwedo">WHAT WE DO</a></li>
        <li><a href="newsevents">NEWS & EVENTS</a></li>
        <li><a href="wherewework">WHERE WE WORK</a></li>
        <li><a href="contactus">CONTACT US</a></li>
    </ul>

</footer>
    


</body>



</html>
